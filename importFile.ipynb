# %% [markdown]
# <a href="https://colab.research.google.com/github/prakaspb/Training-AI/blob/main/importFile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from time import sleep
from random import randint
import os
print("learning how to import works")
# Out:
# learning how to import works
