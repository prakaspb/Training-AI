# %% [markdown]
# <a href="https://colab.research.google.com/github/prakaspb/Training-AI/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/prakaspb/Training-AI.git
# Out:
# Cloning into 'Training-AI'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 30 (delta 7), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (30/30), 16.48 KiB | 16.48 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
print("statateme")
print(" Rich dad")
# Out:
# statateme
